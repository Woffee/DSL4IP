# %%
from PIL import Image, ImageDraw, ImageFont

with Image.open("traffic_sign.jpg") as img:
    
    draw = ImageDraw.Draw(img)
    draw.rectangle(((0, 0), (100, 100)), fill="black")
    draw.text((0, 0), "something123")

# %%
font_path = "/Users/woffee/www/language_design/prototype/font_consolas/CONSOLA.TTF"
font = ImageFont.truetype(font_path, 20)

with Image.open("traffic_sign.jpg") as img:
    
    draw = ImageDraw.Draw(img)
    txt = '123'
    txt_width = 11 * len(txt)
    draw.rectangle(((0, 0), (txt_width, 16)), fill="black")
    
    
    draw.text((0, 0), txt, font=font)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=450x299 at 0x7FA26A47C6D0>
